# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
sales = pd.read_csv('data/매출액.csv', encoding = 'cp949')
sales
# Out:
#     특성별(1)   특성별(2)     특성별(3)                 특성별(4)         2018  \
# 0   특성별(1)   특성별(2)     특성별(3)                 특성별(4)  5천만원 미만 (%)
# 1       전체       소계         소계                     소계         11.6
# 2      업종별    일반음식점         소계                     소계         10.6
# 3      업종별    일반음식점         한식                     소계         11.6
# 4      업종별    일반음식점         중식                     소계          5.8
# 5      업종별    일반음식점         일식                     소계          0.4
# 6      업종별    일반음식점        서양식                     소계          3.3
# 7      업종별    일반음식점     기타 외국식                     소계          0.0
# 8      업종별  일반음식점 외         소계                     소계         12.7
# 9      업종별  일반음식점 외   기관 구내식당업                     소계          3.7
# 10     업종별  일반음식점 외  출장·이동음식점업                     소계          2.3
# 11     업종별  일반음식점 외    기타 음식점업                    제과점          8.3
# 12     업종별  일반음식점 외    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업          7.4
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 24 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   특성별(1)  26 non-null     object
#  1   특성별(2)  26 non-null     object
#  2   특성별(3)  26 non-null     object
#  3   특성별(4)  26 non-null     object
#  4   2018    26 non-null     object
#  5   2018.1  26 non-null     object
#  6   2018.2  26 non-null     object
#  7   2018.3  26 non-null     object
#  8   2018.4  26 non-null     object
#  9   2019    26 non-null     object
#  10  2019.1  26 non-null     object
#  11  2019.2  26 non-null     object
#  12  2019.3  26 non-null     object
#  13  2019.4  26 non-null     object
#  14  2020    26 non-null     object
#  15  2020.1  26 non-null     object
#  16  2020.2  26 non-null     object
#  17  2020.3  26 non-null     object
#  18  2020.4  26 non-null     object
#  19  2021    26 non-null     object
#  20  2021.1  26 non-null     object
# ...

# %%
sales.size
sales.shape
# Out:
# 624
# (26, 24)

# %%
sales.columns
# Out:
# Index(['특성별(1)', '특성별(2)', '특성별(3)', '특성별(4)', '2018', '2018.1', '2018.2',
#        '2018.3', '2018.4', '2019', '2019.1', '2019.2', '2019.3', '2019.4',
#        '2020', '2020.1', '2020.2', '2020.3', '2020.4', '2021', '2021.1',
#        '2021.2', '2021.3', '2021.4'],
#       dtype='object')

# %%
#연도별로 살펴보기 
data_2018 = sales[['특성별(3)','특성별(4)', '2018', '2018.1', '2018.2', '2018.3', '2018.4']]
data_2018
# Out:
#        특성별(3)                 특성별(4)         2018           2018.1  \
# 0      특성별(3)                 특성별(4)  5천만원 미만 (%)  5천만원~1억원 미만 (%)
# 1          소계                     소계         11.6             26.6
# 2          소계                     소계         10.6             24.7
# 3          한식                     소계         11.6             25.3
# 4          중식                     소계          5.8             29.3
# 5          일식                     소계          0.4              9.1
# 6         서양식                     소계          3.3             14.2
# 7      기타 외국식                     소계          0.0             12.4
# 8          소계                     소계         12.7             28.7
# 9    기관 구내식당업                     소계          3.7             15.3
# 10  출장·이동음식점업                     소계          2.3             19.8
# 11    기타 음식점업                    제과점          8.3             27.0
# 12    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업          7.4             22.4
# ...

# %%
data_2018.columns = data_2018.iloc[0]
data_2018
# Out:
# 0      특성별(3)                 특성별(4)  5천만원 미만 (%)  5천만원~1억원 미만 (%)  \
# 0      특성별(3)                 특성별(4)  5천만원 미만 (%)  5천만원~1억원 미만 (%)
# 1          소계                     소계         11.6             26.6
# 2          소계                     소계         10.6             24.7
# 3          한식                     소계         11.6             25.3
# 4          중식                     소계          5.8             29.3
# 5          일식                     소계          0.4              9.1
# 6         서양식                     소계          3.3             14.2
# 7      기타 외국식                     소계          0.0             12.4
# 8          소계                     소계         12.7             28.7
# 9    기관 구내식당업                     소계          3.7             15.3
# 10  출장·이동음식점업                     소계          2.3             19.8
# 11    기타 음식점업                    제과점          8.3             27.0
# 12    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업          7.4             22.4
# ...

# %%
data_2018 = data_2018.drop(index=0)
data_2018
# Out:
# 0      특성별(3)                 특성별(4) 5천만원 미만 (%) 5천만원~1억원 미만 (%)  \
# 1          소계                     소계        11.6            26.6
# 2          소계                     소계        10.6            24.7
# 3          한식                     소계        11.6            25.3
# 4          중식                     소계         5.8            29.3
# 5          일식                     소계         0.4             9.1
# 6         서양식                     소계         3.3            14.2
# 7      기타 외국식                     소계         0.0            12.4
# 8          소계                     소계        12.7            28.7
# 9    기관 구내식당업                     소계         3.7            15.3
# 10  출장·이동음식점업                     소계         2.3            19.8
# 11    기타 음식점업                    제과점         8.3            27.0
# 12    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업         7.4            22.4
# 13    기타 음식점업                  치킨전문점         5.8            23.8
# ...

# %%
data_2018.drop(index=[1,2], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/p9/8hvxfvwd1cbfjjyrzwqff47m0000gn/T/ipykernel_1182/2098706540.py in <module>
# ----> 1 data_2018.drop(index=[1,2], inplace = True)
#       2 data_2018
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
data_2018
data_2018.columns.names=['2018']
# Out:
# 0      특성별(3)                 특성별(4) 5천만원 미만 (%) 5천만원~1억원 미만 (%)  \
# 3          한식                     소계        11.6            25.3
# 4          중식                     소계         5.8            29.3
# 5          일식                     소계         0.4             9.1
# 6         서양식                     소계         3.3            14.2
# 7      기타 외국식                     소계         0.0            12.4
# 8          소계                     소계        12.7            28.7
# 9    기관 구내식당업                     소계         3.7            15.3
# 10  출장·이동음식점업                     소계         2.3            19.8
# 11    기타 음식점업                    제과점         8.3            27.0
# 12    기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업         7.4            22.4
# 13    기타 음식점업                  치킨전문점         5.8            23.8
# 14    기타 음식점업        김밥 및 기타 간이 음식점업        17.2            36.2
# 15    기타 음식점업        간이 음식 포장 판매 전문점        13.9            23.5
# ...

# %%
data_2018
# Out:
# 2018     특성별(3)                 특성별(4) 5천만원 미만 (%) 5천만원~1억원 미만 (%)  \
# 3            한식                     소계        11.6            25.3
# 4            중식                     소계         5.8            29.3
# 5            일식                     소계         0.4             9.1
# 6           서양식                     소계         3.3            14.2
# 7        기타 외국식                     소계         0.0            12.4
# 8            소계                     소계        12.7            28.7
# 9      기관 구내식당업                     소계         3.7            15.3
# 10    출장·이동음식점업                     소계         2.3            19.8
# 11      기타 음식점업                    제과점         8.3            27.0
# 12      기타 음식점업  피자·햄버거·샌드위치 및 유사 음식점업         7.4            22.4
# 13      기타 음식점업                  치킨전문점         5.8            23.8
# 14      기타 음식점업        김밥 및 기타 간이 음식점업        17.2            36.2
# 15      기타 음식점업        간이 음식 포장 판매 전문점        13.9            23.5
# ...
