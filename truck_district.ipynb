# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 전국 푸드트럭 허가 구역 표준 데이터 분석
# -  푸드트럭 영업이 가능하도록 지방자치단체가 허가한 푸드트럭허가구역에 대한 정보

# %%
truck = pd.read_csv('data/전국푸드트럭허가구역표준데이터.csv', encoding = 'cp949')
truck.head()
# Out:
#              허가구역명  장소유형    시도명 시군구명  \
# 0       부산대학교내 장승터     6  부산광역시  금정구
# 1           금양초등학교     6  부산광역시  금정구
# 2  부산가톨릭대학교 로사리오광장     6  부산광역시  금정구
# 3        호계2차현대홈타운     8    경기도  안양시
# 4          안양종합운동장     8    경기도  안양시
#
#                                    소재지도로명주소               소재지지번주소         위도  \
# 0                    부산광역시 금정구 부산대학로 63번길 2      부산광역시 금정구 장전동 40  35.232243
# 1                       부산광역시 금정구 중앙대로 1755   부산광역시 금정구 부곡동 63-27  35.241236
# 2  부산광역시 금정구 오륜대로 57, 부산가톨릭대학교 로사리오광장 (부곡동)       부산광역시 금정구 부곡동 9  35.244677
# 3      경기도 안양시 동안구 경수대로 462 (호계동 호계2차현대홈타운)                   NaN        NaN
# 4                      경기도 안양시 동안구 평촌대로 389  경기도 안양시 동안구 비산동 1023        NaN
#
#            경도  푸드트럭운영대수           허가구역사용료  허가구역운영시작일자  허가구역운영종료일자  \
# 0  129.083825       1.0                 0  2018-04-30  2018-05-04
# 1  129.092025       1.0                 0  2018-08-04  2018-08-05
# 2  129.096872       1.0                 0  2019-09-25  2019-09-25
# ...

# %%
truck.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 336 entries, 0 to 335
# Data columns (total 47 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   허가구역명         336 non-null    object
#  1   장소유형          336 non-null    int64
#  2   시도명           336 non-null    object
#  3   시군구명          336 non-null    object
#  4   소재지도로명주소      235 non-null    object
#  5   소재지지번주소       305 non-null    object
#  6   위도            227 non-null    float64
#  7   경도            228 non-null    float64
#  8   푸드트럭운영대수      245 non-null    float64
#  9   허가구역사용료       336 non-null    object
#  10  허가구역운영시작일자    336 non-null    object
#  11  허가구역운영종료일자    336 non-null    object
#  12  허가구역휴무일       336 non-null    object
#  13  허가구역평일운영시작시각  336 non-null    object
#  14  허가구역평일운영종료시각  336 non-null    object
#  15  허가구역주말운영시작시각  336 non-null    object
#  16  허가구역주말운영종료시각  336 non-null    object
#  17  1월운영시작시각      125 non-null    object
# ...

# %%
#허가구역 종료일자가 현재 날짜 이전인 행은 삭제. 
# 시도별로 구분 >

# %%
truck['시도명'].unique()
# Out:
# array(['부산광역시', '경기도', '전라북도', '인천광역시', '경상남도', '광주광역시', '강원도', '대구광역시',
#        '충청남도', '충청북도', '서울특별시', '대전광역시', '경상북도', '제주특별자치도', '전라남도',
#        '울산광역시'], dtype=object)

# %%
# 시도명, 시군구명 - 지역별로 group화  
# 각 지역별 정보 구체화 (소재지도로명주소, 푸드트럭운영대수, 허가구역사용료, 허가구역 종료일자, 판매 제한 품목)

# %%
group=truck.groupby(truck['시도명'])
group

# %%
group.groups
# Out:
# {'강원도': [25, 26, 27, 28, 29, 30, 31, 32, 35, 36, 92, 93, 94, 95, 96, 97, 117, 120, 129, 194, 195, 196, 197, 198, 228, 229, 230, 231, 234, 235, 271, 272, 273, 297], '경기도': [3, 4, 5, 6, 7, 33, 34, 45, 46, 47, 59, 72, 73, 74, 75, 91, 99, 100, 102, 119, 128, 134, 136, 137, 138, 139, 140, 141, 151, 152, 169, 171, 172, 205, 212, 213, 214, 215, 216, 217, 246, 247, 248, 264, 265, 266, 267, 268, 269, 278, 279, 280, 281, 282, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 298, 314, 315, 316, 328, 329, 330, 331, 332, 333, 334, 335], '경상남도': [11, 12, 13, 14, 16, 17, 18, 19, 20, 90, 118, 130, 131, 132, 133, 165, 166, 167, 168, 201, 203, 204, 206, 223, 224, 225, 226, 227, 237, 241, 242, 243, 244, 245, 274, 275, 276, 306, 307, 308, 309, 310, 311, 312, 313, 318, 319, 320], '경상북도': [98, 126, 127, 147, 148, 149, 150, 207, 208, 220, 304], '광주광역시': [15, 68, 69, 70, 71, 104, 145, 146, 202, 209, 210, 211, 283, 317], '대구광역시': [37, 38, 39, 40, 41, 42, 60, 103, 182, 183, 218, 236], '대전광역시':
# ...

# %%
# 강원도 분석
kang = group.get_group('강원도')

# %%
kang.reset_index(inplace=True, drop=True)

# %%
kang
# Out:
#                          허가구역명  장소유형  시도명 시군구명  \
# 0                       대화전통시장    99  강원도  평창군
# 1                     마하생태관광단지     2  강원도  평창군
# 2                       봉평전통시장    99  강원도  평창군
# 3                     알펜시아 리조트     2  강원도  평창군
# 4                        용평리조트     2  강원도  평창군
# 5                       진부전통시장    99  강원도  평창군
# 6                     평창 휘닉스파크     2  강원도  평창군
# 7                       평창전통시장    99  강원도  평창군
# 8                      오장폭포주차장     2  강원도  정선군
# 9                          만항재     2  강원도  정선군
# 10                     화진포관광지1     2  강원도  고성군
# 11                     화진포관광지2     2  강원도  고성군
# 12                        기타장소    99  강원도  고성군
# 13                   봉포리 상상마당1    99  강원도  고성군
# 14                   봉포리 상상마당2    99  강원도  고성군
# 15                   봉포리 상상마당3    99  강원도  고성군
# 16        관광지-푸드트럭 업소명:비발디푸드트럭    99  강원도  홍천군
# 17           영동선 소초 졸음쉼터(인천방향)     7  강원도  원주시
# 18            인제군농특산물전시판매장 주차장    99  강원도  인제군
# ...
