# %%
import pandas as pd
import numpy as np

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
tour = pd.read_csv('data/업종별지출액.csv', encoding = 'cp949')
tour
# Out:
#        대분류     중분류      대분류 지출액  대분류 지출액 비율      중분류 지출액  중분류 지출액 비율
# 0      쇼핑업   관광기념품  308948966.0        36.5    1140073.0         0.4
# 1      쇼핑업   대형쇼핑몰  308948966.0        36.5  271242270.0        87.8
# 2      쇼핑업  레저용품쇼핑  308948966.0        36.5   34767262.0        11.3
# 3      쇼핑업     면세점  308948966.0        36.5    1799361.0         0.6
# 4      숙박업    기타숙박   33762151.0         4.0   10149428.0        30.1
# 5      숙박업  캠핑장/펜션   33762151.0         4.0        339.0         0.0
# 6      숙박업      콘도   33762151.0         4.0      98788.0         0.3
# 7      숙박업      호텔   33762151.0         4.0   23513596.0        69.6
# 8     식음료업     식음료  427551418.0        50.6  427551418.0       100.0
# 9   여가서비스업     골프장   26389264.0         3.1    8542037.0        32.4
# 10  여가서비스업  관광유원시설   26389264.0         3.1    2671402.0        10.1
# 11  여가서비스업    기타레저   26389264.0         3.1    4797506.0        18.2
# 12  여가서비스업   문화서비스   26389264.0         3.1    9967211.0        37.8
# ...

# %%
from glob import glob
file_names = glob('./data/tour/2018_강남구/*.csv')
file_names
# Out:
# ['./data/tour/2018_강남구/방문자 수.csv',
#  './data/tour/2018_강남구/요일_시간대 별 방문자 집중율.csv',
#  './data/tour/2018_강남구/방문자 수 예측.csv',
#  './data/tour/2018_강남구/방문자 거주지 분포.csv',
#  './data/tour/2018_강남구/방문자 성연령.csv']

# %%
total = pd.DataFrame()
for file_name in file_names :
    temp = pd.read_csv(file_name, sep=',', encoding = 'cp949')
    total = pd.concat([total, temp])

# %%
total
# Out:
#            기준연월        방문자수   요일  방문 시간대  방문자 집중률   광역지자체명     기초지자체명  \
# 0      201801.0  16606631.0  NaN     NaN      NaN      NaN        NaN
# 1      201802.0  13641541.0  NaN     NaN      NaN      NaN        NaN
# 2      201803.0  17377510.0  NaN     NaN      NaN      NaN        NaN
# 3      201804.0  15455335.0  NaN     NaN      NaN      NaN        NaN
# 4      201805.0  15913664.0  NaN     NaN      NaN      NaN        NaN
# 5      201806.0  16483079.0  NaN     NaN      NaN      NaN        NaN
# 6      201807.0  19064006.0  NaN     NaN      NaN      NaN        NaN
# 7      201808.0  16772435.0  NaN     NaN      NaN      NaN        NaN
# 8      201809.0  15750622.0  NaN     NaN      NaN      NaN        NaN
# 9      201810.0  18125926.0  NaN     NaN      NaN      NaN        NaN
# 10     201811.0  17021383.0  NaN     NaN      NaN      NaN        NaN
# 11     201812.0  17670811.0  NaN     NaN      NaN      NaN        NaN
# ...

# %%
total.columns
# Out:
# Index(['기준연월', '방문자수', '요일', '방문 시간대', '방문자 집중률', '광역지자체명', '기초지자체명',
#        '기초지자체별 거주 방문자 수', '방문자 연령', '방문자 수(남성)', '방문자 비율(남성)', '방문자 수(여성)',
#        '방문자 비율(여성)'],
#       dtype='object')

# %%
data = total [['기준연월', '방문자수', '요일', '방문 시간대', '방문자 연령', '방문자 수(남성)',
              '방문자 수(여성)']]
data
# Out:
#            기준연월        방문자수   요일  방문 시간대  방문자 연령   방문자 수(남성)   방문자 수(여성)
# 0      201801.0  16606631.0  NaN     NaN     NaN         NaN         NaN
# 1      201802.0  13641541.0  NaN     NaN     NaN         NaN         NaN
# 2      201803.0  17377510.0  NaN     NaN     NaN         NaN         NaN
# 3      201804.0  15455335.0  NaN     NaN     NaN         NaN         NaN
# 4      201805.0  15913664.0  NaN     NaN     NaN         NaN         NaN
# 5      201806.0  16483079.0  NaN     NaN     NaN         NaN         NaN
# 6      201807.0  19064006.0  NaN     NaN     NaN         NaN         NaN
# 7      201808.0  16772435.0  NaN     NaN     NaN         NaN         NaN
# 8      201809.0  15750622.0  NaN     NaN     NaN         NaN         NaN
# 9      201810.0  18125926.0  NaN     NaN     NaN         NaN         NaN
# 10     201811.0  17021383.0  NaN     NaN     NaN         NaN         NaN
# 11     201812.0  17670811.0  NaN     NaN     NaN         NaN         NaN
# ...

# %%
t1 = pd.read_csv('./data/tour/2018_강남구/방문자 수.csv', encoding = 'cp949')
t2 = pd.read_csv('./data/tour/2018_강남구/요일_시간대 별 방문자 집중율.csv', encoding = 'cp949')
t3 = pd.read_csv('./data/tour/2018_강남구/방문자 성연령.csv', encoding = 'cp949')

# %%
t1
# Out:
#       기준연월        방문자수
# 0   201801  16606631.0
# 1   201802  13641541.0
# 2   201803  17377510.0
# 3   201804  15455335.0
# 4   201805  15913664.0
# 5   201806  16483079.0
# 6   201807  19064006.0
# 7   201808  16772435.0
# 8   201809  15750622.0
# 9   201810  18125926.0
# 10  201811  17021383.0
# 11  201812  17670811.0

# %%
t2
# Out:
#      요일  방문 시간대  방문자 집중률
# 0   일요일  00~06시      1.5
# 1   일요일  06~11시      2.0
# 2   일요일  11~14시      2.2
# 3   일요일  14~18시      3.3
# 4   일요일  18~21시      1.9
# 5   일요일  21~24시      1.1
# 6   월요일  00~06시      1.0
# 7   월요일  06~11시      2.6
# 8   월요일  11~14시      2.4
# 9   월요일  14~18시      3.4
# 10  월요일  18~21시      2.3
# 11  월요일  21~24시      1.4
# 12  화요일  00~06시      1.2
# 13  화요일  06~11시      2.7
# 14  화요일  11~14시      2.5
# 15  화요일  14~18시      3.5
# 16  화요일  18~21시      2.4
# 17  화요일  21~24시      1.5
# 18  수요일  00~06시      1.2
# 19  수요일  06~11시      2.7
# 20  수요일  11~14시      2.6
# 21  수요일  14~18시      3.6
# 22  수요일  18~21시      2.4
# 23  수요일  21~24시      1.5
# 24  목요일  00~06시      1.3
# 25  목요일  06~11시      2.8
# 26  목요일  11~14시      2.6
# 27  목요일  14~18시      3.7
# 28  목요일  18~21시      2.5
# 29  목요일  21~24시      1.6
# 30  금요일  00~06시      1.4
# 31  금요일  06~11시      2.9
# 32  금요일  11~14시      2.8
# 33  금요일  14~18시      3.9
# 34  금요일  18~21시      2.8
# 35  금요일  21~24시      2.0
# ...

# %%
t3
# Out:
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# 0  70세 이상   3570738.0         1.8   2671727.0         1.4
# 1  60~69세  11244713.0         5.7   7016949.0         3.6
# 2  50~59세  18961132.0         9.6  12427782.0         6.3
# 3  40~49세  23496493.0        12.0  13894888.0         7.1
# 4  30~39세  27101695.0        13.8  18962070.0         9.6
# 5  20~29세  21410033.0        10.9  26414371.0        13.4
# 6  10~19세   4042358.0         2.1   4855372.0         2.5
# 7    0~9세    208844.0         0.1    273838.0         0.1

# %%
# 각 지역별로 연도별 방문자 데이터 추출

# %%
from glob import glob
file_names = glob('./data/tour/서울특별시/강남구/방문자수/*.csv')
file_names
# Out:
# ['./data/tour/서울특별시/강남구/방문자수/2019_방문자 수.csv',
#  './data/tour/서울특별시/강남구/방문자수/2018_방문자 수.csv']

# %%
total = pd.DataFrame()
for file_name in file_names :
    temp = pd.read_csv(file_name, sep=',', encoding = 'cp949')
    total = pd.concat([total, temp])

# %%
total
# Out:
#       기준연월        방문자수
# 0   201901  17520407.0
# 1   201902  13590661.0
# 2   201903  18368061.0
# 3   201904  15032635.0
# 4   201905  16335863.0
# 5   201906  16163092.0
# 6   201907  18431958.0
# 7   201908  17988356.0
# 8   201909  16193042.0
# 9   201910  17395700.0
# 10  201911  19699617.0
# 11  201912  19348347.0
# 0   201801  16606631.0
# 1   201802  13641541.0
# 2   201803  17377510.0
# 3   201804  15455335.0
# 4   201805  15913664.0
# 5   201806  16483079.0
# 6   201807  19064006.0
# 7   201808  16772435.0
# 8   201809  15750622.0
# 9   201810  18125926.0
# 10  201811  17021383.0
# 11  201812  17670811.0

# %%
from glob import glob
file_names = glob('./data/tour/서울특별시/강남구/성연령별/*.csv')
file_names
# Out:
# ['./data/tour/서울특별시/강남구/성연령별/2018_방문자 성연령.csv',
#  './data/tour/서울특별시/강남구/성연령별/2019_방문자 성연령.csv']

# %%
total = pd.DataFrame()

for file_name in file_names :
    temp = pd.read_csv(file_name, sep= ',', encoding = 'cp949')
    total = pd.concat([total, temp])

# %%
total
# Out:
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# 0  70세 이상   3570738.0         1.8   2671727.0         1.4
# 1  60~69세  11244713.0         5.7   7016949.0         3.6
# 2  50~59세  18961132.0         9.6  12427782.0         6.3
# 3  40~49세  23496493.0        12.0  13894888.0         7.1
# 4  30~39세  27101695.0        13.8  18962070.0         9.6
# 5  20~29세  21410033.0        10.9  26414371.0        13.4
# 6  10~19세   4042358.0         2.1   4855372.0         2.5
# 7    0~9세    208844.0         0.1    273838.0         0.1
# 0  70세 이상   3997739.0         2.0   3217580.0         1.6
# 1  60~69세  11013886.0         5.5   8059780.0         4.0
# 2  50~59세  18823143.0         9.3  13287763.0         6.6
# 3  40~49세  23766688.0        11.8  14459263.0         7.2
# 4  30~39세  27063374.0        13.4  19897368.0         9.9
# 5  20~29세  21414784.0        10.6  26949512.0        13.4
# 6  10~19세   4302966.0         2.1   4948115.0         2.5
# ...

# %%
total2 = total.groupby(total['방문자 연령'])
total2

# %%
def print_groups(group_obj) :
    for name, group in group_obj :
        print(name)
        print(group)

# %%
print_groups(total2)
# Out:
# 0~9세
#   방문자 연령  방문자 수(남성)  방문자 비율(남성)  방문자 수(여성)  방문자 비율(여성)
# 7   0~9세   208844.0         0.1   273838.0         0.1
# 7   0~9세   305448.0         0.2   360178.0         0.2
# 10~19세
#    방문자 연령  방문자 수(남성)  방문자 비율(남성)  방문자 수(여성)  방문자 비율(여성)
# 6  10~19세  4042358.0         2.1  4855372.0         2.5
# 6  10~19세  4302966.0         2.1  4948115.0         2.5
# 20~29세
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# 5  20~29세  21410033.0        10.9  26414371.0        13.4
# 5  20~29세  21414784.0        10.6  26949512.0        13.4
# 30~39세
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# 4  30~39세  27101695.0        13.8  18962070.0         9.6
# 4  30~39세  27063374.0        13.4  19897368.0         9.9
# 40~49세
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# 3  40~49세  23496493.0        12.0  13894888.0         7.1
# 3  40~49세  23766688.0        11.8  14459263.0         7.2
# 50~59세
#    방문자 연령   방문자 수(남성)  방문자 비율(남성)   방문자 수(여성)  방문자 비율(여성)
# ...

# %%
df_g =
